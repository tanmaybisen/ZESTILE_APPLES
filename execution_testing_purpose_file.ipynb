


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 20)

#_____Lasso____

lasso=Lasso()
parameter={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
lasso_regressor=GridSearchCV(lasso,parameter,scoring="neg_mean_squared_error",cv=5)
obj=lasso_regressor.fit(X,y)
print("y")
print(obj)
print("Y")
# Out:
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.173e+01, tolerance: 2.541e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.471e+01, tolerance: 2.616e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.574e+01, tolerance: 2.500e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.282e+01, tolerance: 2.575e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.886e+01, tolerance: 2.420e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.173e+01, tolerance: 2.541e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.471e+01, tolerance: 2.616e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.574e+01, tolerance: 2.500e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.282e+01, tolerance: 2.575e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.886e+01, tolerance: 2.420e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.173e+01, tolerance: 2.541e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.471e+01, tolerance: 2.616e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.574e+01, tolerance: 2.500e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.282e+01, tolerance: 2.575e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.886e+01, tolerance: 2.420e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.173e+01, tolerance: 2.541e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.471e+01, tolerance: 2.616e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.576e+01, tolerance: 2.500e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.283e+01, tolerance: 2.575e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.886e+01, tolerance: 2.420e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.174e+01, tolerance: 2.541e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.473e+01, tolerance: 2.616e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.587e+01, tolerance: 2.500e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.287e+01, tolerance: 2.575e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.894e+01, tolerance: 2.420e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.286e+01, tolerance: 2.541e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.332e+01, tolerance: 2.616e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.560e+01, tolerance: 2.500e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.370e+01, tolerance: 2.575e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.424e+01, tolerance: 2.420e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.888e+01, tolerance: 2.541e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.957e+01, tolerance: 2.616e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.570e+01, tolerance: 2.500e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.866e+01, tolerance: 2.575e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.424e+01, tolerance: 2.420e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.937e+00, tolerance: 2.541e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.386e+00, tolerance: 2.616e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.802e+00, tolerance: 2.500e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.028e+00, tolerance: 2.575e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.031e+01, tolerance: 2.420e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.816e-01, tolerance: 2.541e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.498e-01, tolerance: 2.616e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.809e-01, tolerance: 2.500e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.430e-01, tolerance: 2.575e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.819e-01, tolerance: 2.420e-02
#   model = cd_fast.enet_coordinate_descent(
# y
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40, 45, 50, 55, 100]},
#              scoring='neg_mean_squared_error')
# Y
# c:\Users\Dell\.conda\envs\FLASK\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.634e+00, tolerance: 3.164e-02
#   model = cd_fast.enet_coordinate_descent(
